# %%
import numpy as np
import pandas as pd

# %%
results = np.load("../ClassroomSim/Outcomes_vary_params/1_ft_distancing/breathing/0.9_p_vax.npy")

# %%
pd.DataFrame(results, columns=["VE_trans", "VE_sus", "p_vax", "droplet_mean", "droplet_sd", "aerosol_mean", "aerosol_sd"])
# Out:
#     VE_trans  VE_sus  p_vax  droplet_mean  droplet_sd  aerosol_mean  \
# 0       0.40    0.00    0.9      0.113965    0.033760      0.000583
# 1       0.40    0.50    0.9      0.065666    0.032957      0.000338
# 2       0.40    0.71    0.9      0.042701    0.037798      0.000229
# 3       0.42    0.00    0.9      0.103127    0.034160      0.000583
# 4       0.42    0.50    0.9      0.061474    0.029284      0.000335
# 5       0.42    0.71    0.9      0.041721    0.037676      0.000221
# 6       0.66    0.00    0.9      0.071019    0.025686      0.000583
# 7       0.66    0.50    0.9      0.046211    0.029142      0.000364
# 8       0.66    0.71    0.9      0.038915    0.033604      0.000287
# 9       0.76    0.00    0.9      0.056803    0.025325      0.000583
# 10      0.76    0.50    0.9      0.041189    0.027815      0.000390
# 11      0.76    0.71    0.9      0.042141    0.034657      0.000349
# 12      0.79    0.00    0.9      0.059041    0.024738      0.000583
# ...
